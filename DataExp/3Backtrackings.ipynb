# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df0 = pd.read_csv('./ejer_0salida1a15.csv')
df1=pd.read_csv('./ejer_1salida1a15.csv')
df2=pd.read_csv('./ejer_2salida1a15.csv')
df0Mean=df0.mean()
df1Mean=df1.mean()
df2Mean=df2.mean()
df = pd.DataFrame({'Backtracking Recursivo': df1Mean, 'Fuerzabruta Iterativo': df0Mean,  'Backtracking c/Poda':df2Mean})
df.plot()
plt.title('Tiempo en funcion de la longitud de la entrada')
plt.ylabel('Tiempo (s)')
plt.xlabel('Longitud de la entrada')
plt.show()
